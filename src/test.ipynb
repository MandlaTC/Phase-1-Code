# %%
import datetime
import os
import platform
from plot_keras_history import show_history, plot_history
from utils.model_utils import create_model
from utils.evaluation_utils import training_evaluation
from training import run_model_training_and_eval

# %%
model = create_model()
history, model, results = run_model_training_and_eval(5)
# Out:
# 2023-08-14 14:21:07.798361: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-08-14 14:21:07.798810: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Metal device set to: Apple M1 Pro
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
#
# Found 449 images belonging to 2 classes.
# Found 111 images belonging to 2 classes.
# Found 240 images belonging to 2 classes.
# 2023-08-14 14:21:13.144943: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# ...

# %%
print(history.history)
show_history(history)
print(results)
# Out:
# {'loss': [32.58360290527344, 8.371234893798828, 3.896635055541992, 1.4454026222229004, 0.39859116077423096], 'accuracy': [0.6013363003730774, 0.7260578870773315, 0.781737208366394, 0.8685969114303589, 0.9198217988014221], 'auc_1': [0.6075893044471741, 0.7405951023101807, 0.8155555725097656, 0.8974602818489075, 0.9652281403541565], 'val_loss': [5.4151129722595215, 11.563981056213379, 2.7788140773773193, 1.6751304864883423, 0.9822447896003723], 'val_accuracy': [0.7837837934494019, 0.684684693813324, 0.8288288116455078, 0.8288288116455078, 0.8918918967247009], 'val_auc_1': [0.7943181991577148, 0.7435064911842346, 0.8597403168678284, 0.9050324559211731, 0.9185065627098083]}
# [1.1951243877410889, 0.8291666507720947, 0.8794434070587158]
